# %% [markdown]
# # Codon optimization tools

# %%
# !git clone https://github.com/ziul-bio/codon_tools_v02.git

# %%
import os
os.chdir('/content/codon_tools_v02')

# !pip install -e .

# %% [markdown]
# # Recoding sequence of interest

# %%
import re
import random
import pandas as pd
import plotnine as pln
from Bio import SeqIO

import sys
sys.path.append('codon_tools_v02')
from examples.recode_to_reference import generate_constructs

# %%
random.seed(1234)
 
# read in the sequence defining target codon frequencies  
target = SeqIO.read('examples/fasta/Mahoney_ORF.fasta', "fasta")

# read in the sequence to optimize (Is expected that the sequences letter to be upper case)
to_optimize = SeqIO.read('examples/fasta/miRFP670nano3.fasta', "fasta")

# do the job  
generate_constructs(to_optimize, target)
# Out:
# completed #1-#3 of GFP_wt
# completed #4 of GFP_wt
# completed #5-#7 of GFP_wt
# completed #8-#10 of GFP_wt
# completed #11-#13 of GFP_wt
# completed #14-#16 of GFP_wt

# %% [markdown]
# # Visualizing constructs

# %%
data = open("examples/recoded/miRFP670nano3_recoded_to_Mahoney_pv_descr.txt").read()
construct_blocks = re.split(r"Construct:", data)[1:]

# %% [markdown]
# # Relative Codon Frequency

# %%
rows = []

for block in construct_blocks:
    name = block.split("\n")[0].strip()
    
    rel = re.search(r"--Relative frequencies--\n(.*?)(?:\n-+|\Z)", block, re.S)

    if rel:
        codons = re.findall(r"([ACGT]{3}):\s*([0-9.]+)", rel.group(1))
        for codon, freq in codons:
            rows.append({
                "Construct": name,
                "Codon": codon,
                "Frequency": float(freq)
            })

df = pd.DataFrame(rows)
df

# %%
ref_name = 'Mahoney_pv'

ref = df[df["Construct"]==ref_name][["Codon","Frequency"]]

ref = ref.rename(columns={"Frequency": "Ref_Frequency"})

freq = df.merge(ref, on="Codon")
freq

# %%
order = (
    freq.groupby("Construct", observed=False)
      # compute the distance to the reference construct (square root of sum of squared differences)
      .apply(lambda x: ((x["Frequency"] - x['Ref_Frequency'])**2).sum()**0.5, include_groups=False)
      .sort_values(ascending=True)
      .index
)

freq["Construct"] = pd.Categorical(freq["Construct"], categories=order, ordered=True)
freq
# Out:
#        Construct Codon  Frequency  Mahoney_pv
# 0     Mahoney_pv   GCA      0.366       0.366
# 1     Mahoney_pv   GCC      0.217       0.217
# 2     Mahoney_pv   GCG      0.106       0.106
# 3     Mahoney_pv   GCT      0.311       0.311
# 4     Mahoney_pv   AGA      0.500       0.500
# ...          ...   ...        ...         ...
# 1093         C16   GTT      0.000       0.159
# 1094         C16   TGG      1.000       1.000
# 1095         C16   ATG      1.000       1.000
# 1096         C16   AAA      0.500       0.508
# 1097         C16   AAG      0.500       0.492
#
# [1098 rows x 4 columns]

# %%
(
    pln.ggplot(freq, pln.aes(x="Codon", y="Construct", fill="Frequency")) +
    pln.geom_tile() +
    pln.theme_bw() +
    pln.theme(
        legend_position="bottom",
        axis_text_x=pln.element_text(angle=90),
        figure_size=(11,6),

    ) +
    pln.labs(title="Codon frequencies in recoded constructs", y="Constructs ordered by similarity to the reference", x="")
)

# %% [markdown]
# # Mutations to stop

# %%
stats = {}
for block in construct_blocks:
    entries = block.split("\n")
    name = entries[0].strip()
    description = entries[1].replace("Description: ", "")

    rel = re.search(r"Mutations to stop: (\d+), CpG count: (\d+), UpA count: (\d+)", block, re.S)

    stats[name] = {
        "Description": description,
        "Mutations to stop": int(rel.groups()[0]),
        "CpG count": int(rel.groups()[1]),
        "UpA count": int(rel.groups()[2])
    }
    #print(name, "Mutations to stop: ", rel.groups()[0], ", CpG count: ", rel.groups()[1], ", UpA count: ", rel.groups()[2])


stats_df = pd.DataFrame.from_dict(stats, orient='index').reset_index()
stats_df.rename(columns={"index": "Construct"}, inplace=True)
stats_df
# Out:
#         Construct                                        Description  \
# 0      Mahoney_pv  Mahoney_pv poliovirus Mahoney strain, entire p...
# 1   miRFP670nano3                                      miRFP670nano3
# 2              C1     codon frequencies matched to Mahoney_pv strain
# 3              C2     codon frequencies matched to Mahoney_pv strain
# 4              C3     codon frequencies matched to Mahoney_pv strain
# 5              C4              minimized mutations to stop, CpG, UpA
# 6              C5  codon frequencies matched to Mahoney_pv strain...
# 7              C6  codon frequencies matched to Mahoney_pv strain...
# 8              C7  codon frequencies matched to Mahoney_pv strain...
# 9              C8  codon frequencies and frequencies of mutations...
# 10             C9  codon frequencies and frequencies of mutations...
# 11            C10  codon frequencies and frequencies of mutations...
# 12            C11  codon frequencies and frequencies of CpG, UpA ...
# 13            C12  codon frequencies and frequencies of CpG, UpA ...
# 14            C13  codon frequencies and frequencies of CpG, UpA ...
# 15            C14  codon frequencies matched to Mahoney_pv, minim...
# 16            C15  codon frequencies matched to Mahoney_pv, minim...
# 17            C16  codon frequencies matched to Mahoney_pv, minim...
#
#     Mutations to stop  CpG count  UpA count
# 0                 898        174        363
# 1                  59          0          0
# 2                  59          0          3
# 3                  59          0          3
# 4                  59          0          3
# 5                  52          0          0
# 6                  59          0          2
# 7                  59          0          3
# 8                  59          0          2
# 9                  60         12         24
# 10                 60         12         24
# 11                 60         12         24
# 12                 52         12         24
# 13                 52         12         24
# 14                 52         12         24
# 15                 59          0          4
# 16                 59          0          3
# 17                 59          0          3

# %%
{
    "C1-3":   "codon frequencies matched to Mahoney_pv strain",
    "C4":     "minimized mutations to stop, CpG, UpA",
    "C5-7":   "codon frequencies matched to Mahoney_pv strain and minimized mutations to stop, CpG, UpA",
    "C8-10":  "codon frequencies and frequencies of mutations to stop, CpG, UpA all matched to Mahoney_pv",
    "C11-13": "codon frequencies and frequencies of CpG, UpA matched to Mahoney_pv, minimized mutations to stop",
    "C14-16": "codon frequencies matched to Mahoney_pv, minimized CpG only ",
}
# Out:
# {'C1-3': 'codon frequencies matched to Mahoney_pv strain',
#  'C4': 'minimized mutations to stop, CpG, UpA',
#  'C5-7': 'codon frequencies matched to Mahoney_pv strain and minimized mutations to stop, CpG, UpA',
#  'C8-10': 'codon frequencies and frequencies of mutations to stop, CpG, UpA all matched to Mahoney_pv',
#  'C11-13': 'codon frequencies and frequencies of CpG, UpA matched to Mahoney_pv, minimized mutations to stop',
#  'C14-16': 'codon frequencies matched to Mahoney_pv, minimized CpG only '}

# %%
order = stats_df.sort_values("Mutations to stop")["Construct"]
stats_df["Construct"] = pd.Categorical(stats_df["Construct"], categories=order, ordered=True)


(
    pln.ggplot(stats_df, pln.aes(x="Construct", y="Mutations to stop")) +
    pln.geom_col() +
    pln.theme_bw() +
    pln.theme(
        panel_grid_major_y=pln.element_blank(),
        figure_size=(10,6),
    ) +
    pln.labs(title="Mutations to stop codons", x="") +
    pln.coord_flip() 
)

# %% [markdown]
# # CpG count

# %%
order = stats_df.sort_values("CpG count")["Construct"]
stats_df["Construct"] = pd.Categorical(stats_df["Construct"], categories=order, ordered=True)


(
    pln.ggplot(stats_df, pln.aes(x="Construct", y="CpG count")) +
    pln.geom_col() +
    pln.theme_bw() +
    pln.theme(
        panel_grid_major_y=pln.element_blank(),
        figure_size=(10,6),
    ) +
    pln.labs(title="CpG count", x="") +
    pln.coord_flip() 
)

# %% [markdown]
# # UpA count

# %%
order = stats_df.sort_values("UpA count")["Construct"]
stats_df["Construct"] = pd.Categorical(stats_df["Construct"], categories=order, ordered=True)


(
    pln.ggplot(stats_df, pln.aes(x="Construct", y="UpA count")) +
    pln.geom_col() +
    pln.theme_bw() +
    pln.theme(
        panel_grid_major_y=pln.element_blank(),
        figure_size=(10,6),
    ) +
    pln.labs(title="UpA count", x="") +
    pln.coord_flip() 
)
